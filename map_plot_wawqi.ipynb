# %%
# !pip3 install folium

# %%
import pandas as pd

data = pd.read_csv('./super_data.csv')
results = pd.read_csv('./wqi_results.csv')

data = pd.concat([data, results], axis=1)
data
# Out:
#        DISTRICT         LOCATION    PH       EC     ALK    SO4  CO3     F  \
# 0     Ahmedabad          Barvala  7.69   4781.0  1100.0  270.0  0.0  3.25
# 1     Ahmedabad       Dhandhuka1  7.56    790.0   290.0   36.0  0.0  2.20
# 2     Ahmedabad            Gamph  7.90   2550.0   640.0   10.0  0.0  0.25
# 3     Ahmedabad          Tagadi1  7.80   1492.0   360.0   15.0  0.0  1.75
# 4     Ahmedabad            Dalod  7.73  14520.0  1010.0  439.0  0.0  3.10
# ...         ...              ...   ...      ...     ...    ...  ...   ...
# 4561    Kutchch         Desalpur  7.42    768.0   150.0   70.0  0.0  0.15
# 4562    Kutchch  Ratanpar Khadir  7.73   4419.0   330.0  310.0  0.0  0.78
# 4563    Kutchch            Rapar  7.60   2942.0   230.0  538.0  0.0  0.93
# 4564    Kutchch             Kuda  7.35   1464.0   500.0   25.0  0.0  1.04
# 4565    Kutchch           Kharoi  7.62   1304.0   230.0   77.0  0.0  0.33
#
#          MG    HCO3  ...  YEAR    NO3      TH      CL      NA     CA     K  \
# 0      48.0  1342.0  ...  2014  17.00   300.0   780.0  1020.0   40.0   0.4
# 1      10.0   354.0  ...  2014  12.00   100.0    43.0   140.0   24.0  17.2
# 2      72.0   781.0  ...  2014  16.00   370.0   461.0   416.0   28.0  37.0
# 3      31.0   439.0  ...  2014  17.00   210.0   191.0   210.0   32.0   5.2
# 4     216.0  1232.0  ...  2014  45.00  1350.0  4361.0  2940.0  180.0  33.0
# ...     ...     ...  ...   ...    ...     ...     ...     ...    ...   ...
# 4561   19.0   183.0  ...  2021   3.20   180.0   113.0    95.0   40.0  10.0
# 4562  112.0   403.0  ...  2021  13.00   701.0  1064.0   712.0   96.0  17.0
# 4563   17.0   281.0  ...  2021  33.00   400.0   567.0   552.0  132.0  26.0
# 4564   36.0   610.0  ...  2021   0.31   410.0   142.0   125.0  104.0  18.0
# 4565   56.0   281.0  ...  2021   1.50   400.0   241.0   105.0   68.0   4.2
#
#        CCME-WQI       WAWQI        EBWQI
# 0     61.555420   38.644111   322.953062
# 1     64.601738    8.988333    68.551642
# 2     69.023569   22.555222   187.772599
# 3     76.746451   14.035111   115.300810
# 4     29.843938  103.398000  1038.036172
# ...         ...         ...          ...
# 4561  60.989717    7.274778    60.166415
# 4562  57.180425   34.582556   331.010335
# 4563  75.149894   23.527667   217.290519
# 4564  87.842858   15.582556   119.304083
# 4565  77.998531   13.182667   113.554477
#
# [4566 rows x 21 columns]

# %%
data = data.replace({
    'Ahmedabad':'Ahmadabad',
    'Bharuch*':'Bharuch',

    'Vadodara*' : 'Vadodara',
    'Vadodra':'Vadodara',

    'Jundagadh':'Junagadh',
    'Junagarh': 'Junagadh',

    'Chhota udepur': 'Dahod',
    'Chhota Udaipur': 'Dahod',

    'Aravalli': 'Sabar Kantha',
    'Arvalli':'Sabar Kantha',

    'Morvi': 'Rajkot',
    'Morbi': 'Rajkot',

    'Dangs-Ahwa':'The Dangs',
    'The dangs':'The Dangs',
    'Dang': 'The Dangs',

    'Kutchch':'Kachchh',
    'Kacchh': 'Kachchh',

    'Porbanadar':'Porbandar',

    'Panchmahals':'Panch Mahals',
    'Panchmahal': 'Panch Mahals',

    'Dohad':'Dahod',
    'Sabarkantha':'Sabar Kantha',
    'Banaskantha': 'Banas Kantha',

    'Tapi': 'Surat',
    'Diu': 'Amreli',
    'Daman': 'Valsad',
    'Mata no madh': 'Kachchh',
    'Mehsana': 'Mahesana',
    'Mahisagar': 'Panch Mahals',
    'Gir Somnath': 'Junagadh',
    'Botad': 'Ahmadabad',
    'Devbhumi Dwarka': 'Jamnagar',
    'Porbander': 'Porbandar',
})
district_data = data.groupby(['DISTRICT'])['WAWQI'].mean().reset_index(name='WAWQI')
district_data
# Out:
#          DISTRICT      WAWQI
# 0       Ahmadabad  36.890359
# 1          Amreli  24.160111
# 2           Anand  19.948363
# 3    Banas Kantha  16.357917
# 4         Bharuch  19.968992
# 5       Bhavnagar  21.147129
# 6           Dahod  16.068122
# 7     Gandhinagar  30.448213
# 8        Jamnagar  23.284396
# 9        Junagadh  23.564190
# 10        Kachchh  29.874626
# 11          Kheda  25.107284
# 12       Mahesana  21.248327
# 13        Narmada  11.583679
# 14        Navsari  14.695974
# 15   Panch Mahals  12.876141
# 16          Patan  43.170092
# 17      Porbandar  30.156906
# 18         Rajkot  23.453221
# 19   Sabar Kantha  18.083130
# 20          Surat  12.305354
# 21  Surendranagar  23.755303
# 22      The Dangs   7.515815
# 23       Vadodara  19.008789
# 24         Valsad   9.828214

# %%
import geopandas as gpd

data = gpd.read_file(
    "./GeoJSON/india_district.geojson"
)

print(type(data))
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
data_gujarat = data[data['NAME_1'] == "Gujarat"]

# %%
districts_2 = data_gujarat['NAME_2']
districts_2
# Out:
# 123        Ahmadabad
# 124           Amreli
# 125            Anand
# 126     Banas Kantha
# 127          Bharuch
# 128        Bhavnagar
# 129            Dahod
# 130      Gandhinagar
# 131         Jamnagar
# 132         Junagadh
# 133          Kachchh
# 134            Kheda
# 135         Mahesana
# 136          Narmada
# 137          Navsari
# 138     Panch Mahals
# 139            Patan
# 140        Porbandar
# 141           Rajkot
# 142     Sabar Kantha
# 143            Surat
# 144    Surendranagar
# 145        The Dangs
# 146         Vadodara
# 147           Valsad
# Name: NAME_2, dtype: object

# %%
import numpy as np

np.setdiff1d(np.array(district_data['DISTRICT']), np.array(districts_2))
# Out:
# array([], dtype=object)

# %%
np.setdiff1d(np.array(districts_2), np.array(district_data['DISTRICT']))
# Out:
# array([], dtype=object)

# %%
# import the folium library
import folium

# initialize the map and store it in a m object
m = folium.Map(location=[22.2587, 71.1924], zoom_start=7)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_701da53fce366c77d1db12a2a3383652 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_701da53fce366c77d1db12a2a3383652&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_701da53fce366c77d1db12a2a3383652 = L.map(
#                 &quot;map_701da53fce366c77d1db12a2a3383652&quot;,
#                 {
#                     center: [22.2587, 71.1924],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d75fe87eee8cea56f34a26f2df55e50 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3d75fe87eee8cea56f34a26f2df55e50.addTo(map_701da53fce366c77d1db12a2a3383652);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Choropleth(
    geo_data=data_gujarat,
    name="choropleth",
    data=district_data,
    columns=["DISTRICT", "WAWQI"],
    key_on="feature.properties.NAME_2",  # Adjust this according to your GeoJSON structure
    fill_color="YlOrRd",  # Adjust the color scale
    fill_opacity=1, 
    line_opacity=1,
    legend_name="WAWQI"
).add_to(m)

m.show_in_browser()
# Out:
# Your map should have been opened in your browser automatically.
# Press ctrl+c to return.

# %%
import io
from PIL import Image

img_data = m._to_png(5)
img = Image.open(io.BytesIO(img_data))
img.save('gujarat_choropleth.png')
